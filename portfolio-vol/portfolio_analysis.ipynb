# %% [markdown]
# # Portfolio Realized Vol
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Kris-SF/data-pipelines/blob/main/portfolio-vol/portfolio_analysis.ipynb) &nbsp;&nbsp;&nbsp; [GitHub repo](https://github.com/Kris-SF/data-pipelines/tree/main/portfolio-vol)
#
# Edit the `WEIGHTS` / `START` / `END` in the second code cell, then **Run All**. Data comes from yfinance (auto-adjusted closes), math uses population covariance (`ddof=0`) on daily log returns.
#
# Works in Google Colab (one-click) and locally in VS Code / Jupyter. The cell below handles both.

# %%
# Bootstrap — runs in both Colab and local Jupyter/VS Code.
# In Colab: clones the repo (so analysis.py / portfolio_vol.py are importable) and installs deps.
# Local: no-op. Run the commented pip line once if you haven't installed requirements yet.
try:
    import google.colab  # type: ignore  # noqa: F401
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    import os
    if not os.path.isdir("data-pipelines"):
        # !git clone --quiet --depth 1 https://github.com/Kris-SF/data-pipelines.git
    # %cd data-pipelines/portfolio-vol
    # %pip install --quiet -r requirements.txt

# Local first-time install (uncomment once, then comment back):
# %pip install -r requirements.txt

# %%
from analysis import run_portfolio_analysis

WEIGHTS = {
    "SPY": 0.50,
    "QQQ": 0.30,
    "TLT": 0.20,
}

START = "2024-01-01"
END   = "2025-01-01"

result = run_portfolio_analysis(WEIGHTS, start=START, end=END)

# %% [markdown]
# `result` holds everything for further poking — e.g. `result.returns`, `result.cov`, `result.corr`, `result.component_ann_vol`, `result.avg_realized_corr`, `result.variance_ratio`.
