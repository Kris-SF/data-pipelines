# %% [markdown]
# # Portfolio Realized Vol
#
# Edit the `WEIGHTS` / `START` / `END` below, then **Run All**. Data comes from yfinance (auto-adjusted closes), math uses population covariance (`ddof=0`) on log returns.

# %%
# One-time setup — uncomment, run once, then comment back out.
# %pip install -r requirements.txt

# %%
from analysis import run_portfolio_analysis

WEIGHTS = {
    "SPY": 0.50,
    "QQQ": 0.30,
    "TLT": 0.20,
}

START = "2024-01-01"
END   = "2025-01-01"

result = run_portfolio_analysis(WEIGHTS, start=START, end=END)

# %% [markdown]
# `result` holds everything for further poking — e.g. `result.returns`, `result.cov`, `result.corr`, `result.component_ann_vol`.
